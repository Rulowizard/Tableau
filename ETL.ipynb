# %%
import pandas as pd
import os

# %%
df201801 = pd.read_csv(os.path.join("..", "Tableau","Data","CSV", "JC-201801-citibike-tripdata.csv"))
df201801["Year"]=2018
df201801["Month"]=1
df201801.head()
len(df201801)
# Out:
# 12677

# %%
df201802 = pd.read_csv(os.path.join("..", "Tableau","Data","CSV", "JC-201802-citibike-tripdata.csv"))
df201802["Year"]=2018
df201802["Month"]=2
df201802.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           134  2018-02-01 07:38:15.8650  2018-02-01 07:40:30.5820
# 1           413  2018-02-01 08:19:35.8160  2018-02-01 08:26:29.6490
# 2            77  2018-02-01 08:31:03.0860  2018-02-01 08:32:20.3510
# 3           404  2018-02-01 15:23:15.0850  2018-02-01 15:29:59.9300
# 4           230  2018-02-01 15:26:01.8240  2018-02-01 15:29:52.5440
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3184      Paulus Hook
# ...

# %%
df201803 = pd.read_csv(os.path.join("..", "Tableau","Data","CSV", "JC-201803-citibike-tripdata.csv"))
df201803["Year"]=2018
df201803["Month"]=3
df201803.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           329  2018-03-01 06:37:37.0380  2018-03-01 06:43:06.5520
# 1           118  2018-03-01 07:37:30.1210  2018-03-01 07:39:28.3910
# 2            76  2018-03-01 08:26:17.9390  2018-03-01 08:27:34.6770
# 3           578  2018-03-01 12:10:36.2160  2018-03-01 12:20:14.8690
# 4           485  2018-03-01 12:21:47.8800  2018-03-01 12:29:53.2990
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3202     Newport PATH
# ...

# %%
df201901 = pd.read_csv(os.path.join("..", "Tableau","Data","CSV", "JC-201901-citibike-tripdata.csv"))
df201901["Year"]=2019
df201901["Month"]=1
df201901.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
df201902 = pd.read_csv(os.path.join("..", "Tableau","Data","CSV", "JC-201902-citibike-tripdata.csv"))
df201902["Year"]=2019
df201902["Month"]=2
df201902.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           142  2019-02-01 15:35:02.0820  2019-02-01 15:37:24.1360
# 1           223  2019-02-01 17:00:46.8900  2019-02-01 17:04:30.5500
# 2           106  2019-02-01 17:08:01.3260  2019-02-01 17:09:47.4400
# 3           370  2019-02-01 17:09:31.2100  2019-02-01 17:15:41.6550
# 4           315  2019-02-01 17:19:53.2490  2019-02-01 17:25:09.1400
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3639       Harborside
# ...

# %%
df201903 = pd.read_csv(os.path.join("..", "Tableau","Data","CSV", "JC-201903-citibike-tripdata.csv"))
df201903["Year"]=2019
df201903["Month"]=3
df201903.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           306  2019-03-01 06:47:08.2110  2019-03-01 06:52:14.7150
# 1           123  2019-03-01 07:30:53.0220  2019-03-01 07:32:56.7770
# 2           328  2019-03-01 08:18:30.4030  2019-03-01 08:23:59.0590
# 3            95  2019-03-01 11:04:47.2020  2019-03-01 11:06:22.8130
# 4           169  2019-03-01 11:51:29.4170  2019-03-01 11:54:19.2120
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3267     Morris Canal
# ...

# %%
df = df201801.append(df201802)
df = df.append(df201803)
df = df.append(df201901)
df = df.append(df201902)
df = df.append(df201903)

# %%
total_rows = len(df201801) + len(df201802) + len(df201803) + len(df201901) + len(df201902) + len(df201903)
total_rows
# Out:
# 106737

# %%
len(df)
# Out:
# 106737

# %%
df.to_csv( "bikes.csv",  index=False)
